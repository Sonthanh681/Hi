# %%
# shift + enter: run code + add row
# cài đặt
# !pip install pillow
# !conda install pillow
# import lớp image
from PIL import Image

# %%
# thư mục chứa hình ảnh
dir = 'C:/HuynhMinhTien/THIGIACMAYTINH/Hinh/'
# đường dẫn đến hình ảnh
image_path = dir +'conmeo.jpg'
print(image_path)
# Out:
# C:/HuynhMinhTien/THIGIACMAYTINH/Hinh/conmeo.jpg

# %%
# sử dụng Image.open() đọc ảnh
img01 = Image.open(image_path)
# hiển thị hình ảnh
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x630>

# %%
# in một số thông tin
# in định dạng ảnh
print("Định dang ảnh: ", img01.format)
# in ra size
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Định dang ảnh:  JPEG
# Kích thước hình ảnh:  (1080, 630)

# %%
# Lưu ảnh và chuyển đổi ảnh
new_img_01_path = dir + '/conmeomoi.JPG'
new_img_png_01_path = dir + '/conmeomoi.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
# đóng tập tin
img01.close()
