# %%
# import thư viện
from PIL import Image
from imgtools import *

# %%
# đường dẫn ảnh 
my_path = 'C:/HuynhMinhTien/THIGIACMAYTINH/Hinh/conmeo2.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x800>

# %%
# định vị khu vực cắt
region = (15, 5, 450, 600)
# cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=435x595>

# %%
# Dán
# Xác định vị trí cần dán
paste_position = (5, 15)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x800>
